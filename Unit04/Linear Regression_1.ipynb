# %% [markdown]
# # Linear Regression

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. 線性迴歸基本概念

# %% [markdown]
# #### 直線
#
# $$f(x) = 1.2x + 0.8$$

# %%
#準備 50 個點
#5-0/50 = 0.1 +....
# 0~5線性切割
x = np.linspace(0, 5, 50)
print(x)
# Out:
# [0.         0.10204082 0.20408163 0.30612245 0.40816327 0.51020408
#  0.6122449  0.71428571 0.81632653 0.91836735 1.02040816 1.12244898
#  1.2244898  1.32653061 1.42857143 1.53061224 1.63265306 1.73469388
#  1.83673469 1.93877551 2.04081633 2.14285714 2.24489796 2.34693878
#  2.44897959 2.55102041 2.65306122 2.75510204 2.85714286 2.95918367
#  3.06122449 3.16326531 3.26530612 3.36734694 3.46938776 3.57142857
#  3.67346939 3.7755102  3.87755102 3.97959184 4.08163265 4.18367347
#  4.28571429 4.3877551  4.48979592 4.59183673 4.69387755 4.79591837
#  4.89795918 5.        ]

# %%
y = 1.2*x + 0.8
y
# Out:
# array([0.8       , 0.92244898, 1.04489796, 1.16734694, 1.28979592,
#        1.4122449 , 1.53469388, 1.65714286, 1.77959184, 1.90204082,
#        2.0244898 , 2.14693878, 2.26938776, 2.39183673, 2.51428571,
#        2.63673469, 2.75918367, 2.88163265, 3.00408163, 3.12653061,
#        3.24897959, 3.37142857, 3.49387755, 3.61632653, 3.73877551,
#        3.86122449, 3.98367347, 4.10612245, 4.22857143, 4.35102041,
#        4.47346939, 4.59591837, 4.71836735, 4.84081633, 4.96326531,
#        5.08571429, 5.20816327, 5.33061224, 5.45306122, 5.5755102 ,
#        5.69795918, 5.82040816, 5.94285714, 6.06530612, 6.1877551 ,
#        6.31020408, 6.43265306, 6.55510204, 6.67755102, 6.8       ])

# %%
#畫圖
plt.scatter(x,y)
plt.plot(x, 1.2*x+0.8, 'r')
plt.show()

# %% [markdown]
# #### add noise
#
# $$f(x) + \varepsilon(x)$$

# %%
y = 1.2*x + 0.8 + 0.6*np.random.randn(50)
print(y)
# Out:
# [-0.58310669  0.33440061 -0.99571602  1.62222213  0.36386758  0.6241022
#   1.7259541   1.49747101  2.59405476  2.79214838  2.15927624  1.8717167
#   2.91304492  2.31423558  2.98031146  2.88031769  2.62436119  3.18207498
#   3.24110483  3.7338636   3.42907633  2.44940746  3.18929208  3.7828799
#   3.20237842  4.26850954  4.07436246  3.94212453  3.46027657  4.48665496
#   5.31262235  5.30543167  4.02140968  6.42001138  4.25897427  5.16217316
#   4.73100886  5.36228332  5.14439407  5.8211309   6.85150251  6.6170156
#   6.14693793  6.23911632  5.2676172   6.53364609  6.96977214  7.24510171
#   6.0473659   7.10816792]

# %%
plt.scatter(x,y)
plt.plot(x, 1.2*x + 0.8, 'r')
plt.show()

# %%
from sklearn.linear_model import LinearRegression
regr = LinearRegression()

# %%
regr
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# 要求資料轉換<br>
#
# $$[x_1, x_2, \ldots, x_{50}]$$
#
# ==>
#
# $$[[x_1], [x_2], \ldots, [x_{50}]]$$
#
#
# 矩陣的概念

# %%
print(x.shape)
X = x.reshape(-1,1)
X.shape
# Out:
# (50,)
# (50, 1)

# %%
regr.fit(X,y) #套用y的公式預測
# Out:
# LinearRegression()

# %%
Y = regr.predict(X) #Y是預測出來的值
print(Y)
# Out:
# [0.52565478 0.65989446 0.79413414 0.92837383 1.06261351 1.19685319
#  1.33109287 1.46533256 1.59957224 1.73381192 1.86805161 2.00229129
#  2.13653097 2.27077066 2.40501034 2.53925002 2.6734897  2.80772939
#  2.94196907 3.07620875 3.21044844 3.34468812 3.4789278  3.61316748
#  3.74740717 3.88164685 4.01588653 4.15012622 4.2843659  4.41860558
#  4.55284527 4.68708495 4.82132463 4.95556431 5.089804   5.22404368
#  5.35828336 5.49252305 5.62676273 5.76100241 5.8952421  6.02948178
#  6.16372146 6.29796114 6.43220083 6.56644051 6.70068019 6.83491988
#  6.96915956 7.10339924]

# %%
#了解你的訓練參數
regr.get_params()
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}

# %%
plt.scatter(x, y) #原本 
plt.plot(x, Y, 'ro') #預測
plt.show()
#calculate mse
mse = np.sum((Y-y)**2) / len(y)
print(mse)
# Out:
# 0.4171268909706692

# %%
#Y=WX+b
W=regr.coef_#斜率
W
# Out:
# array([1.31554889])

# %%
b=regr.intercept_ #截距
b
# Out:
# 0.5256547764138513

# %%
Y
# Out:
# array([0.52565478, 0.65989446, 0.79413414, 0.92837383, 1.06261351,
#        1.19685319, 1.33109287, 1.46533256, 1.59957224, 1.73381192,
#        1.86805161, 2.00229129, 2.13653097, 2.27077066, 2.40501034,
#        2.53925002, 2.6734897 , 2.80772939, 2.94196907, 3.07620875,
#        3.21044844, 3.34468812, 3.4789278 , 3.61316748, 3.74740717,
#        3.88164685, 4.01588653, 4.15012622, 4.2843659 , 4.41860558,
#        4.55284527, 4.68708495, 4.82132463, 4.95556431, 5.089804  ,
#        5.22404368, 5.35828336, 5.49252305, 5.62676273, 5.76100241,
#        5.8952421 , 6.02948178, 6.16372146, 6.29796114, 6.43220083,
#        6.56644051, 6.70068019, 6.83491988, 6.96915956, 7.10339924])

# %%
#可以將新的x資料帶入算出結果
W*3+b
# Out:
# array([4.47230146])

# %%
y
# Out:
# array([ 0.27525339,  1.33994008,  0.91197999, -0.20320858,  1.89085355,
#         0.60847933,  1.48341042,  0.93030304,  1.35044448,  2.53660118,
#         3.19097507,  1.59325492,  3.29520382,  2.39603642,  2.42674534,
#         3.32204164,  2.85852214,  2.90697684,  2.52972766,  3.11008526,
#         2.90785658,  3.85680041,  3.44705739,  3.42994352,  2.59456672,
#         3.79364206,  4.66116825,  3.79851919,  4.45159162,  4.30879935,
#         4.91409624,  4.70701615,  6.28523753,  4.07812527,  5.17605873,
#         4.62142594,  4.77138525,  4.78797527,  6.15181021,  4.81071081,
#         5.84798456,  5.19384327,  6.18938522,  5.53159052,  6.32867975,
#         5.78822922,  7.0023755 ,  7.53394173,  6.22492988,  5.53340938])
